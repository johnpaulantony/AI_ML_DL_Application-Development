# %%
import joblib

gold_price_model=joblib.load('gold_price_prediction_model.pkl')

# %%
# unknown data

# create a dataframe (single row)
import pandas as pd

new_data=pd.DataFrame([{
    'year':2021,
    'month':1,
    'day':2,
    'dayofweek':0, # 0-monday, 6-sunday
    'Standard Gold (22 K)':4000.0
}])

# %%
new_data
# Out:
#    year  month  day  dayofweek  Standard Gold (22 K)
# 0  2021      1    2          0                4000.0

# %%
# make the prediction

prediction=gold_price_model.predict(new_data)

print("predicted 24k gold rate",prediction[0])
# Out:
# predicted 24k gold rate 4209.17
