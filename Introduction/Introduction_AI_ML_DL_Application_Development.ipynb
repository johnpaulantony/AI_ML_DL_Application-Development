# %%
AI - to make a computer or machine to be an intelligent one
ML - prediction for past data based on the patterns. It is a subset of AI  - Gold price prediction, based patient lab test(c) heart disease prediction.
     99% strutured data , table format. ML supports most of the time use nuemrical data for the input . ML algorthims used math formulae
     - CPU (small amount of data)


DL - inspried by human brain. It is a subset of ML. supports structured and unstructured data (image, text, video)
   - accuarte results , Massive amount of data,Complex data (GPU (massive amount of data)

AI Systems
  types of AI systems

# %% [markdown]
# Agenda for the entire training
#      1. steps for AI, ML and DL powered application development from scratch
#
#      2. ML terminologies -
#                      supervised  - input and output (features and label), X and Y
#                                  - classification
#                                  - Regression
#                      unsupervised - clustering - input or features or X
#                       - reinforcement - game developemnt,
#
#                       model - build or develop
#
#                       deploy the model into web app or desktop app
#
#                       fine tune the model, AWS
#
#                       5 to 6 application development
#
#       3. DL terminologies
#                       image data  - staic and dynamic(video)
#
#                       model - build or develop
#
#                       deploy the model into web app or desktop app
#
#                       fine tune the model, AWS
#
#                       5 to 6 application development
#
#       4. AI
#                 NLP genAI
#                 model - build or develop
#
#                 deploy the model into web app or desktop app
#
#                 fine tune the model, AWS
#
#                 5 to 6 application development

# %%
steps for AI, ML and DL powered application development from scratch

AI
   Define the problem
   gather and prepare Data
   choose AI technique - rule-based logic, expert systems, NLP,ML or DL models
   select AI Tools & frameworks - python (NLTK, openAI API, langchain)
   Develop and integrate AI models
   Test AI system
   deploy and monitor


ML
  define the problem
  collect & prepare the data
  select ML alg
  train the model
  evaluate the model
  optimize and tune hyperparameters
  deploy model in production - WEB API, WEB APP
  monitor and update the model


DL
 Problem def and data collection
 data preprocessing & Augumentation
 choose Deep learning model
 build neural network architure
 train model with GPU/TPU
 Evaluate and fine tune
 deploy using API's or Edge Devices
 continous learning & updates

# %%
AI
   AI based sentiment analyis tool - customer reviews - Text - Deep Learning (NLP - ML and DL alg RNN - LSTM)
   AI powered resume screeneer - DL (NLP)
   AI chatbot or VA with speech recognition - NLP - two branches (NLU, NLG)
   AI email spam filter - NLP ( Text Preprocessing )+ ML ( classification )
   AI personlaized learning -  COursera AI, Duolingo - RL
   AI Legal Document Analysis - OPenAI API , NLP
   AI medical diagonis - image data - DL,  structured data - ML or DL , medical document history- DL (NLP)


ML

  Stock price prediction

  sturctured data ( fatures , label )  - creadit scoring and loan approval

  Blood test results or prediction

  traffic prediction

  Gold price Prediction

  house price prediction

  weather forecast prediction

  credit care fraud detection
  sales prediction
  HR employee attrition prediction


DL

Face Recognition system

Text Generation
object detection using YOLO
speech emotion recog
Medical image diagonis
speech to text conversion

recommendation system

driverless car


real time translation

image classification

traffic prediction
 NLP tasks

# %% [markdown]
# **AI-Powered Applications (Rule-Based & AI APIs)**
# AI Chatbot using OpenAI API – Build a chatbot that answers user queries using OpenAI’s GPT model.
#
# AI-Powered Resume Screener – Automate resume screening based on predefined criteria.
#
# AI-Based Sentiment Analysis Tool – Analyze customer reviews using NLP techniques.
#
# AI Virtual Assistant with Speech Recognition – Use Google Speech-to-Text API and NLP for voice commands.
#
# AI-Powered Email Classifier – Categorize emails into spam, promotions, and primary using AI rules.
#
# AI-Based Document Summarizer – Use LangChain or Hugging Face models to summarize large documents.
#
# AI-Powered Fake News Detector – Classify news articles as real or fake using AI APIs.
#
# **ML-Powered Applications (Machine Learning-Based Projects)**
# House Price Prediction using Linear Regression – Predict house prices based on features like area and location.
#
# Customer Segmentation using K-Means Clustering – Group customers based on shopping behavior.
#
# Loan Approval Prediction using Decision Trees – Predict loan eligibility based on financial history.
#
# Spam Email Classification using Naïve Bayes – Classify emails as spam or ham.
#
# Stock Price Prediction using Time Series Analysis – Predict stock market trends using historical data.
#
# E-commerce Recommendation System using Collaborative Filtering – Suggest products based on user behavior.
#
# Medical Diagnosis using Random Forest – Predict diseases based on patient symptoms.
#
# HR Employee Attrition Prediction – Use ML to predict if an employee is likely to leave.
#
# Credit Card Fraud Detection – Identify fraudulent transactions using classification models.
#
# Chatbot Intent Recognition – Train an ML model to recognize user intents for chatbot interactions.
#
# **DL-Powered Applications (Deep Learning-Based Projects)**
# Face Recognition System using CNN (OpenCV + TensorFlow) – Detect and recognize faces in images and videos.
#
# Handwritten Digit Recognition using MNIST Dataset (CNN) – Classify handwritten digits from images.
#
# Text Generation using GPT-2 (Transformers NLP) – Generate human-like text using pre-trained transformers.
#
# Object Detection using YOLO (Computer Vision) – Detect multiple objects in images using YOLOv8.
#
# Speech Emotion Recognition using LSTMs (Audio Processing) – Detect emotions from voice recordings.
#
# Image Caption Generator using LSTM + CNN – Generate captions for images automatically.
#
# Self-Driving Car Simulation using Reinforcement Learning – Train a virtual car using RL.
#
# AI-Powered Medical Image Diagnosis (CNN) – Detect diseases from X-ray or MRI images.
#
# Style Transfer using GANs (Deep Learning for Art) – Apply artistic filters to images using GANs.
#
# Autonomous Drone Navigation using Deep Learning – Train a drone to navigate obstacles.
#
# AI-Powered Music Generation (RNN/LSTM-Based) – Create music based on deep learning.

# %% [markdown]
# ***AI-Powered Applications (Rule-Based & AI APIs)***
# AI-Powered Resume Analyzer – Use NLP to extract key skills and match them with job descriptions.
#
# AI-Based Personal Finance Manager – Automate expense tracking and budgeting using AI.
#
# AI-Generated Interview Questions – Generate customized interview questions based on job roles.
#
# AI Legal Document Analyzer – Extract important clauses from legal documents using NLP.
#
# AI-Powered Language Translator – Build a real-time language translation app using OpenAI API.
#
# AI-Powered Recipe Recommendation System – Suggest recipes based on available ingredients.
#
# AI Fake Review Detector – Detect fake product reviews using AI models.
#
# AI-Based Personal Shopping Assistant – Recommend fashion products based on user preferences.
#
# AI-Powered Code Auto-Completer – Use OpenAI Codex to suggest code snippets in an IDE.
#
# AI-Powered Mood-Based Music Player – Suggest songs based on user mood detection.
#
# AI-Based Traffic Light Controller – Optimize traffic lights using AI-based decision-making.
#
# AI-Powered Weather Prediction – Use AI models to predict weather conditions more accurately.
#
# ***🧠 ML-Powered Applications (Machine Learning Projects)***
# Real-Time Air Quality Prediction – Predict air pollution levels using ML models.
#
# AI-Powered Crop Disease Prediction – Detect plant diseases from images using ML.
#
# ML-Based Personal Investment Advisor – Predict stock or crypto market trends.
#
# AI-Powered Fake News Detector – Identify fake news using NLP techniques.
#
# ML-Based Personalized Learning Assistant – Suggest learning paths based on student performance.
#
# AI-Powered Smart Resume Screener – Automate job shortlisting based on candidate skills.
#
# AI-Powered Mental Health Chatbot – Provide emotional support using NLP-based chatbots.
#
# AI-Based Road Accident Severity Prediction – Predict accident risks based on road conditions.
#
# Personalized Ad Recommendation System – Suggest ads based on user interaction history.
#
# AI-Powered Home Energy Consumption Predictor – Optimize energy usage for smart homes.
#
# AI-Powered Sports Analytics App – Predict sports match outcomes using ML.
#
# AI-Based Healthcare Chatbot – Provide symptom-based health advice using AI models.
#
# AI-Powered Supply Chain Optimization – Predict demand and optimize inventory.
#
# ***🖥️ DL-Powered Applications (Advanced Deep Learning Projects)***
# AI-Powered Virtual Try-On System (GANs + OpenCV) – Allow users to try clothes/makeup virtually.
#
# Deepfake Video Generator (GANs) – Generate realistic AI-powered deepfake videos.
#
# AI-Powered Sign Language Translator – Convert sign language gestures to text using CNN + LSTM.
#
# AI-Based Lip Reading System – Recognize speech by analyzing lip movements in videos.
#
# AI-Powered Gesture Control System – Control a computer using hand gestures.
#
# AI-Based Sports Player Performance Prediction – Predict an athlete’s performance using deep learning.
#
# AI-Powered Autonomous Drone Navigation – Train a drone to navigate obstacles using RL.
#
# AI-Based Smart Traffic Monitoring System – Analyze traffic density using AI-powered vision models.
#
# AI-Based Sleep Pattern Analysis – Detect sleep stages from EEG signals.
#
# Deep Learning-Based Video Summarizer – Summarize long videos into short highlights.
#
# AI-Powered Autonomous Cooking Assistant – Detect cooking progress and suggest recipes.
#
# AI-Based Handwritten Signature Verification – Verify digital signatures using DL models.
#
# AI-Powered Virtual Interior Designer – Suggest furniture placement based on room dimensions.
#
# AI-Powered Disaster Prediction System – Predict earthquakes or floods using satellite data.

# %% [markdown]
# *** AI-Powered Real-Time Applications (Detailed Explanation)***
# 1️⃣ AI-Powered Virtual Assistants
# How it works: Uses NLP (Natural Language Processing) and machine learning to understand and respond to user queries.
#
# Examples: Siri, Alexa, Google Assistant.
#
# Technical Insight: Speech recognition (DeepSpeech, WaveNet), NLP (BERT, GPT-4), AI-powered voice synthesis.
#
# 2️⃣ AI-Based Resume Screening
# How it works: Uses NLP to scan resumes for keywords, skills, and experience.
#
# Examples: LinkedIn Talent Insights, HireVue.
#
# Technical Insight: NLP models like BERT, Resume Parsing APIs.
#
# 3️⃣ AI-Powered Email Spam Filter
# How it works: Uses ML algorithms to classify emails as spam or legitimate.
#
# Examples: Gmail Spam Filter, Outlook.
#
# Technical Insight: Naïve Bayes Classifier, Random Forest.
#
# 4️⃣ AI Personalized Learning
# How it works: Adapts course content based on user behavior.
#
# Examples: Coursera AI, Duolingo.
#
# Technical Insight: Reinforcement Learning (RL), Adaptive Learning Models.
#
# 5️⃣ AI Legal Document Analysis
# How it works: AI scans legal documents for errors, compliance issues, and potential risks.
#
# Examples: Ross Intelligence, Kira Systems.
#
# Technical Insight: NLP-based contract analysis, BERT models.
#
# 6️⃣ AI-Powered Chatbots
# How it works: Uses AI to generate responses in customer support.
#
# Examples: ChatGPT, IBM Watson Assistant.
#
# Technical Insight: NLP models (GPT-4, Dialogflow).
#
# 7️⃣ AI-Powered Fraud Detection
# How it works: Detects anomalies in financial transactions.
#
# Examples: PayPal, Mastercard AI.
#
# Technical Insight: Anomaly detection models (Isolation Forest, Autoencoder).
#
# 8️⃣ AI News Aggregation
# How it works: Collects and personalizes news articles based on user preferences.
#
# Examples: Google News, Apple News.
#
# Technical Insight: Text summarization (T5, Pegasus).
#
# 9️⃣ AI-Powered Medical Diagnosis
# How it works: Analyzes symptoms and medical reports for disease prediction.
#
# Examples: IBM Watson Health, Tempus Labs.
#
# Technical Insight: CNNs for X-ray analysis, BERT for medical texts.
#
# 🔟 AI-Powered Code Assistants
# How it works: Suggests code completions and detects errors.
#
# Examples: GitHub Copilot, Tabnine.
#
# Technical Insight: Deep learning models like OpenAI Codex.
#
# ***🔹 ML-Powered Real-Time Applications (Detailed Explanation)***
# 1️⃣ Fraud Detection in Banking
# How it works: Identifies suspicious transactions.
#
# Examples: Visa, PayPal.
#
# Technical Insight: Logistic Regression, Anomaly Detection.
#
# 2️⃣ Dynamic Pricing
# How it works: Prices change dynamically based on demand.
#
# Examples: Uber Surge Pricing, Amazon.
#
# Technical Insight: Regression models, Time Series Analysis.
#
# 3️⃣ Credit Scoring & Loan Approval
# How it works: Predicts credit risk.
#
# Examples: FICO, LendingClub.
#
# Technical Insight: Decision Trees, Random Forest.
#
# 4️⃣ Supply Chain & Demand Forecasting
# How it works: Predicts stock demand.
#
# Examples: Walmart, Amazon.
#
# Technical Insight: ARIMA, LSTM.
#
# 5️⃣ Real-Time Sentiment Analysis
# How it works: Analyzes customer feedback.
#
# Examples: Twitter AI, Brandwatch.
#
# Technical Insight: LSTM, Transformers.
#
# 6️⃣ Stock Market Prediction
# How it works: Forecasts stock trends.
#
# Examples: Bloomberg AI.
#
# Technical Insight: LSTM, Reinforcement Learning.
#
# 7️⃣ Predictive Maintenance
# How it works: Predicts machine failures.
#
# Examples: Siemens AI, GE AI.
#
# Technical Insight: CNNs, RNNs.
#
# 8️⃣ Real-Time Traffic Prediction
# How it works: Optimizes routes for users.
#
# Examples: Google Maps, Waze.
#
# Technical Insight: Time Series Forecasting.
#
# 9️⃣ Weather Forecasting
# How it works: Predicts climate conditions.
#
# Examples: AccuWeather, IBM Weather.
#
# Technical Insight: Neural Networks.
#
# 🔟 AI-Powered Retail Analytics
# How it works: Analyzes sales patterns.
#
# Examples: Amazon, Walmart AI.
#
# Technical Insight: K-Means Clustering, XGBoost.
#
# ***🔹 DL-Powered Real-Time Applications (Detailed Explanation)***
# 1️⃣ Face Recognition for Security
# How it works: Identifies faces in images.
#
# Examples: Apple Face ID, Airport Security.
#
# Technical Insight: Convolutional Neural Networks (CNNs).
#
# 2️⃣ Medical Image Diagnosis
# How it works: Analyzes X-rays for disease detection.
#
# Examples: IBM Watson Health.
#
# Technical Insight: CNNs, Transfer Learning.
#
# 3️⃣ Autonomous Vehicles
# How it works: Self-driving car navigation.
#
# Examples: Tesla, Waymo.
#
# Technical Insight: Deep Reinforcement Learning.
#
# 4️⃣ Video Surveillance & Anomaly Detection
# How it works: Detects suspicious activities.
#
# Examples: Smart CCTV.
#
# Technical Insight: YOLO (You Only Look Once) model.
#
# 5️⃣ AI-Powered Real-Time Translation
# How it works: Translates text and speech.
#
# Examples: Google Translate, DeepL.
#
# Technical Insight: Transformers (BERT, GPT).
#
# 6️⃣ Speech-to-Text Conversion
# How it works: Converts speech into text.
#
# Examples: Otter.ai, Microsoft Speech API.
#
# Technical Insight: RNNs, CTC Loss.
#
# 7️⃣ Image Classification
# How it works: Detects objects in images.
#
# Examples: Google Lens.
#
# Technical Insight: CNNs, ResNet.
#
# 8️⃣ Deepfake Detection
# How it works: Identifies manipulated images.
#
# Examples: Facebook AI.
#
# Technical Insight: GANs (Generative Adversarial Networks).
#
# 9️⃣ AI-Powered Voice Assistants
# How it works: Generates realistic speech responses.
#
# Examples: Alexa, Siri.
#
# Technical Insight: WaveNet, Tacotron.
#
# 🔟 DL-Powered Smart Traffic Management
# How it works: Optimizes traffic signals.
#
# Examples: Smart Cities.
#
# Technical Insight: Reinforcement Learning.
